# %% [markdown]
# # Format data for NLP

# %% [markdown]
# ## Open CSV File

# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\TEJAS\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
data_cleaned = pd.read_csv('yelp_data_cleaned.csv', na_values = ['nan'])
data_cleaned
# Out:
#                                                    text                 date  \
# 0     If I could give half a star I would, I'm from ...  2012-11-06 03:44:19
# 1     I used to live in Pa. and have a thing for Ita...  2012-11-06 03:53:13
# 2     Tried and true Southern BBQ!  The drive thru w...  2015-04-29 23:34:13
# 3     Place is in a strip mall. Very unassuming plac...  2015-12-21 02:21:10
# 4     Food is always good and service is excellent. ...  2016-06-23 16:46:56
# ...                                                 ...                  ...
# 3516  Terrible service.  Short girl was very rude.  ...  2021-10-27 22:05:02
# 3517  Disgrace to the Chipotle name. Avoid this loca...  2021-09-02 00:31:18
# 3518  Arrived at opening. Dinning room tables and fl...  2021-10-24 16:33:29
# 3519  This location is highly nasty and unsanitary! ...  2021-10-02 02:07:01
# 3520  Brand new but filthy. Trash overflowing, dirty...  2021-11-07 23:54:35
#
# ...

# %% [markdown]
# ## Preprocess Review Data

# %%
text_doc = data_cleaned['text']
text_doc_list = list(text_doc)
text_doc_test = text_doc_list[0:]
text_doc_test_2 = text_doc.iloc[0:]

# %% [markdown]
# ### Import and clean text dataset

# %%
# Run this cell ONLY ONCE, then comment it out

#import nltk
#nltk.download()

# %%
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
import string

stop = set(stopwords.words('english'))
exclude = set(string.punctuation)
lemma = WordNetLemmatizer()

# %%
def clean(doc):
    try:
        number_free = ''.join([i for i in doc if not i.isdigit()])
        stop_free = ' '.join([i for i in number_free.lower().split() if i not in stop and len(i)>2])
        punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
        normalized = ' '.join(lemma.lemmatize(word) for word in punc_free.split())
    except:
        print(doc)
    return normalized

# %%
doc_clean = [clean(doc).split() for doc in text_doc_test]
doc_clean
# Out:
# [['could',
#   'give',
#   'half',
#   'star',
#   'would',
#   'im',
#   'tx',
#   'anyone',
#   'think',
#   'bbq',
#   'willing',
#   'apologize',
#   'led',
#   'believe',
#   'bbq',
#   'like',
#   'ordered',
#   'sample',
#   'platter',
#   'horrific',
#   'chicken',
#   'looked',
#   'tasted',
#   'like',
#   'frozen',
#   'pressed',
#   'meat',
#   'rib',
#   'cartilage',
#   'sausage',
#   'bland',
#   'sauce',
#   'walmart',
#   'basic',
#   'sauce',
#   'cup',
#   'sugar',
#   'thrown',
#   'in',
#   'extremely',
#   'overpriced',
#   'ummm',
#   'child',
#   'plate',
#   'what',
#   'seemed',
#   'like',
#   'would',
#   'never',
#   'recommend',
#   'place',
#   'anyone'],
#  ['used',
#   'live',
#   'pa',
#   'thing',
#   'italian',
#   'hoagy',
#   'jersey',
#   'mike',
#   'italian',
#   'sub',
#   'plain',
#   'awesome',
#   'closest',
#   'tasted',
#   'pa',
#   'hoagy',
#   'really',
#   'love',
#   'fact',
#   'meat',
#   'sliced',
#   'fresh',
#   'order',
# ...

# %%
# Importing Gensim
from gensim import *
from gensim.corpora import Dictionary

# creating the term dictionary for our corpus, where every unique term is assigned an index
dictionary = corpora.Dictionary(doc_clean)

# converting corpus into Document Term Matrix using using dictionary prepared above
doc_term_matrix = [dictionary.doc2bow(doc) for doc in doc_clean]

# %%
import gensim
LDA = gensim.models.ldamodel.LdaModel

# Running and traininng LDA model on the Document Term Matrix
ldamodel = LDA(doc_term_matrix, num_topics = 50, id2word = dictionary, passes = 25)

# %%
print(ldamodel.print_topics())
# Out:
# [(24, '0.026*"time" + 0.020*"food" + 0.015*"pretty" + 0.015*"good" + 0.012*"like" + 0.012*"get" + 0.010*"would" + 0.009*"come" + 0.009*"cook" + 0.008*"wanted"'), (29, '0.027*"chickfila" + 0.016*"slow" + 0.014*"shake" + 0.014*"bad" + 0.013*"waste" + 0.012*"managed" + 0.011*"far" + 0.010*"location" + 0.010*"there" + 0.010*"probably"'), (11, '0.030*"good" + 0.024*"dressing" + 0.019*"chicken" + 0.016*"food" + 0.016*"meat" + 0.015*"cheese" + 0.014*"green" + 0.012*"nothing" + 0.012*"potato" + 0.011*"mac"'), (38, '0.021*"crew" + 0.018*"funny" + 0.017*"soy" + 0.017*"beer" + 0.013*"ready" + 0.013*"get" + 0.013*"best" + 0.012*"right" + 0.012*"brew" + 0.011*"neighbor"'), (14, '0.032*"chicken" + 0.015*"place" + 0.013*"got" + 0.012*"im" + 0.011*"home" + 0.011*"it" + 0.010*"take" + 0.010*"ive" + 0.009*"good" + 0.009*"food"'), (18, '0.072*"fry" + 0.054*"chicken" + 0.053*"wing" + 0.038*"waffle" + 0.031*"burger" + 0.020*"fried" + 0.017*"good" + 0.014*"best" + 0.014*"tender" + 0.014*"ranch"'), (46, '0
# ...

# %%
import pyLDAvis
import pyLDAvis.gensim
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(ldamodel, doc_term_matrix, dictionary)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster      Freq
# topic
# 7      0.207813  0.197128       1        1  8.408809
# 45     0.209239 -0.143789       2        1  8.380689
# 28     0.163975  0.009179       3        1  6.740103
# 8      0.218285 -0.069075       4        1  5.660410
# 6      0.142788 -0.112076       5        1  5.138585
# 17     0.157247  0.112286       6        1  4.614266
# 43     0.157400  0.108067       7        1  4.055457
# 46     0.152911  0.120263       8        1  3.464286
# 4      0.115248 -0.184470       9        1  3.019038
# 9      0.116468 -0.033623      10        1  2.995484
# 14     0.149448 -0.017369      11        1  2.878597
# 49     0.119004 -0.123020      12        1  2.805638
# 22     0.111311 -0.071105      13        1  2.704501
# 24     0.119362  0.078658      14        1  2.405706
# 13     0.104662 -0.133134      15        1  2.397861
# 30     0.046888 -0.049367      16        1  2.077693
# ...

# %% [markdown]
# ## Latent Semantic Search (LSA)

# %%
# Preprocessing
text_doc = text_doc_test_2.str.replace("[^a-zA-Z#]"," ")

# removing short words
text_doc = text_doc.apply(lambda x: ' '.join([w for w in x.split() if len(w)>3]))

# make all text lowercase
text_doc = text_doc.apply(lambda x: x.lower())

# %%
text_doc
# Out:
# 0       could give half star would, from anyone that t...
# 1       used live have thing italian hoagies, jersey m...
# 2       tried true southern bbq! drive thru fast worke...
# 3       place strip mall. very unassuming place. pulle...
# 4       food always good service excellent. they alway...
#                               ...
# 3516    terrible service. short girl very rude. veggie...
# 3517    disgrace chipotle name. avoid this location co...
# 3518    arrived opening. dinning room tables floors di...
# 3519    this location highly nasty unsanitary! food co...
# 3520    brand filthy. trash overflowing, dirty tables....
# Name: text, Length: 3521, dtype: object

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

# tokenization
tokenized_doc = text_doc.apply(lambda x: x.split())

# remove stop words
tokenized_doc = tokenized_doc.apply(lambda x: [item for item in x if item not in stop_words])

# de-tokenization
lemma = WordNetLemmatizer()
detokenized_doc = []

for i in range(len(text_doc_test_2)):
    t = ' '.join(tokenized_doc[i])
    t = ' '.join(lemma.lemmatize(word) for word in t.split())
    detokenized_doc.append(t)
    
text_doc = detokenized_doc

# %%
text_doc
# Out:
# ["could give half star would, anyone think bbq, willing apologize believe like. ordered sample platter, horrific, chicken looked tasted like frozen pressed meat, ribs.... cartilage, sausage, bland.... sauce.... walmart basic sauce cup sugar thrown in.... extremely overpriced ummm.... child's plate (what seemed like). would never recommend place anyone.",
#  "used live thing italian hoagies, jersey mike italian sub plain awesome, closest tasted hoagies. really love fact meat sliced fresh order, for, slice meat extra extra meat, can't comment sandwich can't past taste italian subs, thus stars, ever another sandwich update stars.",
#  "tried true southern bbq! drive thru fast worker friendly, efficient professional! ordered pound slaw. convenience drive thru amazing smokin' hot! feedback: register need facing worker cannot screen glare. boo!",
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(stop_words='english', max_features=1000, max_df = 0.5, smooth_idf=True)
x= vectorizer.fit_transform(text_doc)
x.shape
# Out:
# (3521, 1000)

# %%
from sklearn.decomposition import TruncatedSVD

# SVD represent documents and terms in vectors
svd_model = TruncatedSVD(n_components=50, algorithm='randomized', n_iter=100, random_state=526)

svd_model.fit(x)

len(svd_model.components_)
# Out:
# 50

# %%
svd_model.components_
# Out:
# array([[ 0.0107043 ,  0.01745364,  0.00853776, ...,  0.0105421 ,
#          0.01990687,  0.0079152 ],
#        [-0.01210257, -0.00691368, -0.00110676, ..., -0.01856665,
#          0.01610588, -0.01589478],
#        [-0.00279764,  0.00110625, -0.00842265, ..., -0.0033272 ,
#         -0.00472249,  0.00506105],
#        ...,
#        [-0.00146176, -0.00159043,  0.02382725, ..., -0.00156487,
#          0.02229777,  0.0015751 ],
#        [ 0.00197134, -0.00076092, -0.00547424, ..., -0.00394435,
#         -0.00666402, -0.01134487],
#        [ 0.00388185,  0.02061352, -0.02176955, ...,  0.0037333 ,
#         -0.00985906, -0.00276952]])

# %%
terms = vectorizer.get_feature_names_out()

for i, comp in enumerate(svd_model.components_):
    terms_comp = zip(terms, comp)
    sorted_terms = sorted(terms_comp, key=lambda x: x[1], reverse=True)[:10]
    print("Topic "+str(i)+": ", end=' ')
    print(' '.join([x[0] for x in sorted_terms]))
# Out:
# Topic 0:  good place great chicken service time order like best restaurant
# Topic 1:  great sushi best friendly nashville place good amazing love chicken
# Topic 2:  chicken heat burn slow level best nashville tender fried waffle
# Topic 3:  sushi roll ve chicken best nashville good ordered order fish
# Topic 4:  good really pretty crab like shrimp sauce steak cheese salad
# Topic 5:  crab best delicious pizza chinese mexican ve place taco amazing
# Topic 6:  pizza place good order love really delivery wing people crust
# Topic 7:  pizza great sushi crab ordered like shrimp roll seafood cheese
# Topic 8:  pizza great chinese best crab service ve order shrimp delivery
# Topic 9:  friendly staff order delicious breakfast definitely super fresh good sushi
# Topic 10:  crab place order shrimp seafood amazing cake good rangoon love
# Topic 11:  time ve love great steak taco fish order coffee sandwich
# Topic 12:  order chinese great restaurant delivery rice area nice fried breakfast
# ...

# %% [markdown]
# ## Analyze reviews by Low Rating

# %%
data_lowrating = data_cleaned[data_cleaned['review_stars'] < 4]

# %%
text_doc_low = data_lowrating['text']

# %%
text_doc = text_doc_low.str.replace("[^a-zA-Z#]", " ")
text_doc = text_doc.apply(lambda x: ' '.join([w for w in x.split() if len(w) > 3]))
text_doc = text_doc.apply(lambda x: x.lower())
text_doc.index = np.arange(0, len(text_doc))

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
tokenized_doc = text_doc.apply(lambda x: x.split())
tokenized_doc = tokenized_doc.apply(lambda x: [item for item in x if item not in stop_words])
lemma = WordNetLemmatizer()

detokenized_doc = []
for i in range(len(text_doc_low)):
    t = ' '.join(tokenized_doc[i])
    t = ' '.join(lemma.lemmatize(word) for word in t.split())
    detokenized_doc.append(t)
    
text_doc = detokenized_doc

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(stop_words='english', max_features=1000, max_df=0.5, smooth_idf=True)
X = vectorizer.fit_transform(text_doc)
terms = vectorizer.get_feature_names_out()

# %%
from sklearn.decomposition import TruncatedSVD

svd_model = TruncatedSVD(n_components=50, algorithm='randomized', n_iter=100, random_state=526)
svd_model.fit(X)

len(svd_model.components_)

for i, comp in enumerate(svd_model.components_):
    terms_comp = zip(terms, comp)
    sorted_terms = sorted(terms_comp, key= lambda x: x[1], reverse=True)[:10]
    print(f"Topic {str(i)}: ", end='')
    print(' '.join(x[0] for x in sorted_terms))
# Out:
# Topic 0: order time place service good chicken like ordered minute table
# Topic 1: chicken good like sauce sushi better pretty roll flavor cheese
# Topic 2: pizza delivery jet crust store order driver wing called large
# Topic 3: chicken order drive ordered called minute tender sandwich told wing
# Topic 4: service rude customer drive place good employee better need staff
# Topic 5: chicken customer rude dirty manager employee service pizza table restaurant
# Topic 6: location time steak ve rude customer service worst manager server
# Topic 7: service drive slow minute pizza wait terrible waited chicken worst
# Topic 8: order service sushi good terrible customer roll took pretty wrong
# Topic 9: place dirty order time location chicken table took clean wrong
# Topic 10: sushi roll time rice chinese ve place terrible hibachi hour
# Topic 11: dirty location bread drive sushi sandwich roll order restaurant line
# ...

# %% [markdown]
# ## Analyze reviews by High Rating

# %%
data_highrating = data_cleaned[data_cleaned['review_stars'] >= 4]
text_doc_high = data_highrating['text']

# %%
text_doc = text_doc_high.str.replace("[^a-zA-Z#]", " ")
text_doc = text_doc.apply(lambda x: ' '.join([w for w in x.split() if len(w) > 3]))
text_doc = text_doc.apply(lambda x: x.lower())
text_doc.index = np.arange(0, len(text_doc))

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
tokenized_doc = text_doc.apply(lambda x: x.split())
tokenized_doc = tokenized_doc.apply(lambda x: [item for item in x if item not in stop_words])
lemma = WordNetLemmatizer()

detokenized_doc = []
for i in range(len(text_doc_low)):
    t = ' '.join(tokenized_doc[i])
    t = ' '.join(lemma.lemmatize(word) for word in t.split())
    detokenized_doc.append(t)
    
text_doc = detokenized_doc

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(stop_words='english', max_features=1000, max_df=0.5, smooth_idf=True)
X = vectorizer.fit_transform(text_doc)
terms = vectorizer.get_feature_names_out()

# %%
from sklearn.decomposition import TruncatedSVD

svd_model = TruncatedSVD(n_components=50, algorithm='randomized', n_iter=100, random_state=526)
svd_model.fit(X)

len(svd_model.components_)

for i, comp in enumerate(svd_model.components_):
    terms_comp = zip(terms, comp)
    sorted_terms = sorted(terms_comp, key= lambda x: x[1], reverse=True)[:10]
    print(f"Topic {str(i)}: ", end='')
    print(' '.join(x[0] for x in sorted_terms))
# Out:
# Topic 0: good place great sushi service best time chicken friendly restaurant
# Topic 1: sushi roll nashville favorite japanese chef ramen sapporo best rolls
# Topic 2: great service amazing place friendly staff breakfast coffee atmosphere love
# Topic 3: good really nice roll sushi pretty salad steak like service
# Topic 4: chinese good great best service nashville prices area price restaurant
# Topic 5: good friendly staff crab delicious area clean taco definitely amazing
# Topic 6: crab great chicken roll lunch friendly soup fried shrimp delicious
# Topic 7: chicken staff friendly breakfast coffee love place biscuit good little
# Topic 8: crab place amazing love seafood shrimp rangoon cake good soup
# Topic 9: amazing ve good best taco service time order sushi recommend
# Topic 10: taco restaurant mexican amazing chicken clean salsa margarita fried best
# Topic 11: love order taco fresh delicious delivery service nice lunch chinese
# ...
